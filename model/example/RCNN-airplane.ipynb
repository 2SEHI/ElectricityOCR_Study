# %%
# !unzip Images.zip

# %%
# !unzip Airplanes_Annotations.zip

# %%
import os,cv2,keras
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# %%
path = "Images"
annot = "Airplanes_Annotations"

# %%
for e,i in enumerate(os.listdir(annot)):
    if e < 10:
        filename = i.split(".")[0]+".jpg"
        print(filename)
        img = cv2.imread(os.path.join(path,filename))
        df = pd.read_csv(os.path.join(annot,i))
        plt.imshow(img)
        for row in df.iterrows():
            x1 = int(row[1][0].split(" ")[0])
            y1 = int(row[1][0].split(" ")[1])
            x2 = int(row[1][0].split(" ")[2])
            y2 = int(row[1][0].split(" ")[3])
            cv2.rectangle(img,(x1,y1),(x2,y2),(255,0,0), 2)
        plt.figure()
        plt.imshow(img)
        break
# Out:
# airplane_188.jpg
# [[[220 219 215]
#   [219 218 214]
#   [216 215 211]
#   ...
#   [182 178 173]
#   [173 169 164]
#   [147 143 138]]
#
#  [[221 220 216]
#   [219 218 214]
#   [216 215 211]
#   ...
#   [168 164 159]
#   [153 149 144]
#   [150 146 141]]
#
#  [[221 220 216]
#   [219 218 214]
#   [216 215 211]
#   ...
#   [131 128 120]
#   [159 156 148]
#   [164 161 153]]
#
#  ...
#
#  [[168 162 149]
#   [167 159 146]
#   [165 155 145]
#   ...
#   [126 112 100]
#   [120 106  94]
#   [138 124 112]]
#
#  [[166 158 145]
#   [160 152 139]
#   [155 146 133]
#   ...
#   [133 119 107]
#   [124 110  98]
#   [122 108  96]]
#
#  [[158 150 137]
#   [151 143 130]
#   [145 133 121]
#   ...
#   [114 100  88]
#   [107  93  81]
#   [105  91  79]]]
#                  1
# 0  172 212 230 253

# %% [markdown]
# - setUseOptimized : Turns on/off available optimization. The function turns on or off the optimized code in OpenCV. Some optimization can not be enabled or disabled, but, for example, most of SSE code in OpenCV can be temporarily turned on or off this way.

# %%
cv2.setUseOptimized(True);
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()

# %%
im = cv2.imread(os.path.join(path,"42850.jpg"))
ss.setBaseImage(im)
ss.switchToSelectiveSearchFast()
rects = ss.process()
imOut = im.copy()
for i, rect in (enumerate(rects)):
    x, y, w, h = rect
#     print(x,y,w,h)
#     imOut = imOut[x:x+w,y:y+h]
    cv2.rectangle(imOut, (x, y), (x+w, y+h), (0, 255, 0), 1, cv2.LINE_AA)
# plt.figure()
plt.imshow(imOut)

# %%
train_images=[]
train_labels=[]

# %%
def get_iou(bb1, bb2):
    assert bb1['x1'] < bb1['x2']
    assert bb1['y1'] < bb1['y2']
    assert bb2['x1'] < bb2['x2']
    assert bb2['y1'] < bb2['y2']

    x_left = max(bb1['x1'], bb2['x1'])
    y_top = max(bb1['y1'], bb2['y1'])
    x_right = min(bb1['x2'], bb2['x2'])
    y_bottom = min(bb1['y2'], bb2['y2'])

    if x_right < x_left or y_bottom < y_top:
        return 0.0

    intersection_area = (x_right - x_left) * (y_bottom - y_top)

    bb1_area = (bb1['x2'] - bb1['x1']) * (bb1['y2'] - bb1['y1'])
    bb2_area = (bb2['x2'] - bb2['x1']) * (bb2['y2'] - bb2['y1'])

    iou = intersection_area / float(bb1_area + bb2_area - intersection_area)
    assert iou >= 0.0
    assert iou <= 1.0
    return iou

# %%
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()

# %% [markdown]
# 무작위로 그려진 selective_segmentation 중에서 좌표와 멀면 0 , 좌표와 가까우면 1으로 레이블 설정

# %%
for e,i in enumerate(os.listdir(annot)):
    try:
        if i.startswith("airplane"):
            filename = i.split(".")[0]+".jpg"
            print(e,filename)
            image = cv2.imread(os.path.join(path,filename))
            df = pd.read_csv(os.path.join(annot,i))
            gtvalues=[]
            for row in df.iterrows():
                x1 = int(row[1][0].split(" ")[0])
                y1 = int(row[1][0].split(" ")[1])
                x2 = int(row[1][0].split(" ")[2])
                y2 = int(row[1][0].split(" ")[3])
                gtvalues.append({"x1":x1,"x2":x2,"y1":y1,"y2":y2})
            # Set a image used by switch functions to initialize the class    
            ss.setBaseImage(image)
            # Switch to fast but low recall Selective Search method
            ss.switchToSelectiveSearchFast()
            # run selective search segmentation on input image
            ssresults = ss.process()
            # 출력할 이미지생성
            imout = image.copy()
            counter = 0
            falsecounter = 0
            flag = 0
            fflag = 0
            bflag = 0
            # 원본이미지에 그려진 search segmentation의 수만큼 순회
            for e,result in enumerate(ssresults):
                # 
                if e < 2000 and flag == 0:
                    for gtval in gtvalues:
                        # search segmentation의 왼쪽 상단좌표와 width, height취득
                        x,y,w,h = result
                        # 
                        iou = get_iou(gtval,{"x1":x,"x2":x+w,"y1":y,"y2":y+h})
                        if counter < 30:
                            if iou > 0.70:
                                timage = imout[y:y+h,x:x+w]
                                resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
                                train_images.append(resized)
                                train_labels.append(1)
                                counter += 1
                        else :
                            fflag =1
                        if falsecounter <30:
                            if iou < 0.3:
                                timage = imout[y:y+h,x:x+w]
                                resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
                                train_images.append(resized)
                                train_labels.append(0)
                                falsecounter += 1
                        else :
                            bflag = 1
                    if fflag == 1 and bflag == 1:
                        print("inside")
                        flag = 1
    except Exception as e:
        print(e)
        print("error in "+filename)
        continue

# %%
X_new = np.array(train_images)
y_new = np.array(train_labels)

# %%
X_new.shape
# Out:
# (30229, 224, 224, 3)

# %%
from keras.layers import Dense
from keras import Model
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.vgg16 import VGG16

# %%
vggmodel = VGG16(weights='imagenet', include_top=True)
vggmodel.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 3s 0us/step
# 553476096/553467096 [==============================] - 3s 0us/step
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
for layers in (vggmodel.layers)[:15]:
    print(layers)
    layers.trainable = False
# Out:
# <keras.engine.input_layer.InputLayer object at 0x7fda1602c190>
# <keras.layers.convolutional.Conv2D object at 0x7fda160204d0>
# <keras.layers.convolutional.Conv2D object at 0x7fda15d70810>
# <keras.layers.pooling.MaxPooling2D object at 0x7fda15d019d0>
# <keras.layers.convolutional.Conv2D object at 0x7fd8238b4dd0>
# <keras.layers.convolutional.Conv2D object at 0x7fd8238bd950>
# <keras.layers.pooling.MaxPooling2D object at 0x7fd8238b4650>
# <keras.layers.convolutional.Conv2D object at 0x7fd8238c6410>
# <keras.layers.convolutional.Conv2D object at 0x7fd8238d0210>
# <keras.layers.convolutional.Conv2D object at 0x7fd8238d05d0>
# <keras.layers.pooling.MaxPooling2D object at 0x7fd8238c6b90>
# <keras.layers.convolutional.Conv2D object at 0x7fd8238dd290>
# <keras.layers.convolutional.Conv2D object at 0x7fd8238e2a50>
# <keras.layers.convolutional.Conv2D object at 0x7fd8238dc890>
# <keras.layers.pooling.MaxPooling2D object at 0x7fd8238ef410>

# %%
X= vggmodel.layers[-2].output

# %%
predictions = Dense(2, activation="softmax")(X)

# %%
model_final = Model(inputs = vggmodel.input, outputs = predictions)

# %%
from tensorflow import keras
opt = keras.optimizers.Adam(learning_rate=0.01)

# %%
model_final.compile(loss = keras.losses.categorical_crossentropy, optimizer = opt, metrics=["accuracy"])

# %%
model_final.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dense (Dense)                (None, 2)                 8194
# =================================================================
# Total params: 134,268,738
# Trainable params: 126,633,474
# Non-trainable params: 7,635,264
# _________________________________________________________________

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer

# %%
class MyLabelBinarizer(LabelBinarizer):
    def transform(self, y):
        Y = super().transform(y)
        if self.y_type_ == 'binary':
            return np.hstack((Y, 1-Y))
        else:
            return Y
    def inverse_transform(self, Y, threshold=None):
        if self.y_type_ == 'binary':
            return super().inverse_transform(Y[:, 0], threshold)
        else:
            return super().inverse_transform(Y, threshold)

# %%
lenc = MyLabelBinarizer()
Y =  lenc.fit_transform(y_new)

# %%
X_train, X_test , y_train, y_test = train_test_split(X_new,Y,test_size=0.10)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (27206, 224, 224, 3) (3023, 224, 224, 3) (27206, 2) (3023, 2)

# %%
trdata = ImageDataGenerator(horizontal_flip=True, vertical_flip=True, rotation_range=90)
traindata = trdata.flow(x=X_train, y=y_train)
tsdata = ImageDataGenerator(horizontal_flip=True, vertical_flip=True, rotation_range=90)
testdata = tsdata.flow(x=X_test, y=y_test)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %% [markdown]
# ModelCheckpoint : [https://deep-deep-deep.tistory.com/53](https://deep-deep-deep.tistory.com/53)
# ### <수정 사항>
# - `period=1` => `save_freq='epoch'`

# %%
checkpoint = ModelCheckpoint("ieeercnn_vgg16_1.h5", monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', save_freq='epoch')
early = EarlyStopping(monitor='val_loss', min_delta=0, patience=100, verbose=1, mode='auto')

# %% [markdown]
# - `Model.fit_generator(generator= traindata, .... )` => `Model.fit(traindata, .....)`

# %%
hist = model_final.fit(traindata, steps_per_epoch= 10, epochs= 1000, validation_data= testdata, validation_steps=2, callbacks=[checkpoint,early])
# Out:
# Epoch 1/1000
# 10/10 [==============================] - 16s 2s/step - loss: 0.3389 - accuracy: 0.8656 - val_loss: 0.2595 - val_accuracy: 0.9062
#
# Epoch 00001: val_loss improved from inf to 0.25948, saving model to ieeercnn_vgg16_1.h5
# Epoch 2/1000
# 10/10 [==============================] - 16s 2s/step - loss: 0.3165 - accuracy: 0.8687 - val_loss: 0.2388 - val_accuracy: 0.9062
#
# Epoch 00002: val_loss improved from 0.25948 to 0.23876, saving model to ieeercnn_vgg16_1.h5
# Epoch 3/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3252 - accuracy: 0.8813 - val_loss: 0.3030 - val_accuracy: 0.8906
#
# Epoch 00003: val_loss did not improve from 0.23876
# Epoch 4/1000
# 10/10 [==============================] - 16s 2s/step - loss: 0.2953 - accuracy: 0.8969 - val_loss: 0.3140 - val_accuracy: 0.8750
#
# Epoch 00004: val_loss did not improve from 0.23876
# Epoch 5/1000
# 10/10 [==============================] - 16s 2s/step - loss: 0.3378 - accuracy: 0.8375 - val_loss: 0.2869 - val_accuracy: 0.8906
#
# Epoch 00005: val_loss did not improve from 0.23876
# Epoch 6/1000
# 10/10 [==============================] - 16s 2s/step - loss: 0.3721 - accuracy: 0.8531 - val_loss: 0.3362 - val_accuracy: 0.8750
#
# Epoch 00006: val_loss did not improve from 0.23876
# Epoch 7/1000
# 10/10 [==============================] - 16s 2s/step - loss: 0.3077 - accuracy: 0.8531 - val_loss: 0.1899 - val_accuracy: 0.9219
#
# Epoch 00007: val_loss improved from 0.23876 to 0.18987, saving model to ieeercnn_vgg16_1.h5
# Epoch 8/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3004 - accuracy: 0.8687 - val_loss: 0.2602 - val_accuracy: 0.8750
#
# Epoch 00008: val_loss did not improve from 0.18987
# Epoch 9/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3564 - accuracy: 0.8438 - val_loss: 0.2919 - val_accuracy: 0.8906
#
# Epoch 00009: val_loss did not improve from 0.18987
# Epoch 10/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3099 - accuracy: 0.8781 - val_loss: 0.3089 - val_accuracy: 0.8594
#
# Epoch 00010: val_loss did not improve from 0.18987
# Epoch 11/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2971 - accuracy: 0.8687 - val_loss: 0.1853 - val_accuracy: 0.9375
#
# Epoch 00011: val_loss improved from 0.18987 to 0.18534, saving model to ieeercnn_vgg16_1.h5
# Epoch 12/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2607 - accuracy: 0.8938 - val_loss: 0.3420 - val_accuracy: 0.8438
#
# Epoch 00012: val_loss did not improve from 0.18534
# Epoch 13/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3059 - accuracy: 0.8781 - val_loss: 0.2494 - val_accuracy: 0.8906
#
# Epoch 00013: val_loss did not improve from 0.18534
# Epoch 14/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3565 - accuracy: 0.8406 - val_loss: 0.3314 - val_accuracy: 0.8594
#
# Epoch 00014: val_loss did not improve from 0.18534
# Epoch 15/1000
# 10/10 [==============================] - 16s 2s/step - loss: 0.3002 - accuracy: 0.8750 - val_loss: 0.3267 - val_accuracy: 0.8438
#
# Epoch 00015: val_loss did not improve from 0.18534
# Epoch 16/1000
# 10/10 [==============================] - 16s 2s/step - loss: 0.3968 - accuracy: 0.8562 - val_loss: 0.3248 - val_accuracy: 0.8438
#
# Epoch 00016: val_loss did not improve from 0.18534
# Epoch 17/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3490 - accuracy: 0.8594 - val_loss: 0.2037 - val_accuracy: 0.9062
#
# Epoch 00017: val_loss did not improve from 0.18534
# Epoch 18/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3378 - accuracy: 0.8344 - val_loss: 0.2867 - val_accuracy: 0.8438
#
# Epoch 00018: val_loss did not improve from 0.18534
# Epoch 19/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3514 - accuracy: 0.8719 - val_loss: 0.2965 - val_accuracy: 0.8750
#
# Epoch 00019: val_loss did not improve from 0.18534
# Epoch 20/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2783 - accuracy: 0.8844 - val_loss: 0.3663 - val_accuracy: 0.8281
#
# Epoch 00020: val_loss did not improve from 0.18534
# Epoch 21/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2882 - accuracy: 0.8687 - val_loss: 0.3535 - val_accuracy: 0.8281
#
# Epoch 00021: val_loss did not improve from 0.18534
# Epoch 22/1000
# 10/10 [==============================] - 16s 2s/step - loss: 0.3841 - accuracy: 0.8469 - val_loss: 0.2491 - val_accuracy: 0.9062
#
# Epoch 00022: val_loss did not improve from 0.18534
# Epoch 23/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3323 - accuracy: 0.8469 - val_loss: 0.3594 - val_accuracy: 0.8125
#
# Epoch 00023: val_loss did not improve from 0.18534
# Epoch 24/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3464 - accuracy: 0.8594 - val_loss: 0.2961 - val_accuracy: 0.8906
#
# Epoch 00024: val_loss did not improve from 0.18534
# Epoch 25/1000
# 10/10 [==============================] - 16s 2s/step - loss: 1.1686 - accuracy: 0.8562 - val_loss: 0.3087 - val_accuracy: 0.8750
#
# Epoch 00025: val_loss did not improve from 0.18534
# Epoch 26/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3107 - accuracy: 0.8562 - val_loss: 0.3210 - val_accuracy: 0.8906
#
# Epoch 00026: val_loss did not improve from 0.18534
# Epoch 27/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3089 - accuracy: 0.8562 - val_loss: 0.4014 - val_accuracy: 0.8438
#
# Epoch 00027: val_loss did not improve from 0.18534
# Epoch 28/1000
# 10/10 [==============================] - 16s 2s/step - loss: 0.3814 - accuracy: 0.8281 - val_loss: 0.2733 - val_accuracy: 0.8906
#
# Epoch 00028: val_loss did not improve from 0.18534
# Epoch 29/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2999 - accuracy: 0.8781 - val_loss: 0.2578 - val_accuracy: 0.9219
#
# Epoch 00029: val_loss did not improve from 0.18534
# Epoch 30/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2925 - accuracy: 0.8938 - val_loss: 0.2512 - val_accuracy: 0.8906
#
# Epoch 00030: val_loss did not improve from 0.18534
# Epoch 31/1000
# 10/10 [==============================] - 16s 2s/step - loss: 0.2851 - accuracy: 0.8844 - val_loss: 0.2693 - val_accuracy: 0.8594
#
# Epoch 00031: val_loss did not improve from 0.18534
# Epoch 32/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2642 - accuracy: 0.8938 - val_loss: 0.2622 - val_accuracy: 0.8594
#
# Epoch 00032: val_loss did not improve from 0.18534
# Epoch 33/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3352 - accuracy: 0.8562 - val_loss: 0.3632 - val_accuracy: 0.8281
#
# Epoch 00033: val_loss did not improve from 0.18534
# Epoch 34/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3292 - accuracy: 0.8594 - val_loss: 0.2562 - val_accuracy: 0.8750
#
# Epoch 00034: val_loss did not improve from 0.18534
# Epoch 35/1000
# 10/10 [==============================] - 16s 2s/step - loss: 0.3025 - accuracy: 0.8594 - val_loss: 0.3214 - val_accuracy: 0.8438
#
# Epoch 00035: val_loss did not improve from 0.18534
# Epoch 36/1000
# 10/10 [==============================] - 16s 2s/step - loss: 0.3288 - accuracy: 0.8562 - val_loss: 0.2438 - val_accuracy: 0.8594
#
# Epoch 00036: val_loss did not improve from 0.18534
# Epoch 37/1000
# 10/10 [==============================] - 16s 2s/step - loss: 0.3169 - accuracy: 0.8656 - val_loss: 0.3375 - val_accuracy: 0.8750
#
# Epoch 00037: val_loss did not improve from 0.18534
# Epoch 38/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3055 - accuracy: 0.8594 - val_loss: 0.4052 - val_accuracy: 0.7969
#
# Epoch 00038: val_loss did not improve from 0.18534
# Epoch 39/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2547 - accuracy: 0.8938 - val_loss: 0.2631 - val_accuracy: 0.8594
#
# Epoch 00039: val_loss did not improve from 0.18534
# Epoch 40/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3380 - accuracy: 0.8687 - val_loss: 0.2473 - val_accuracy: 0.9062
#
# Epoch 00040: val_loss did not improve from 0.18534
# Epoch 41/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3104 - accuracy: 0.8625 - val_loss: 0.3369 - val_accuracy: 0.8594
#
# Epoch 00041: val_loss did not improve from 0.18534
# Epoch 42/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3329 - accuracy: 0.8656 - val_loss: 0.2205 - val_accuracy: 0.8906
#
# Epoch 00042: val_loss did not improve from 0.18534
# Epoch 43/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3471 - accuracy: 0.8562 - val_loss: 0.5185 - val_accuracy: 0.7344
#
# Epoch 00043: val_loss did not improve from 0.18534
# Epoch 44/1000
# 10/10 [==============================] - 16s 2s/step - loss: 0.2812 - accuracy: 0.8813 - val_loss: 0.4088 - val_accuracy: 0.8594
#
# Epoch 00044: val_loss did not improve from 0.18534
# Epoch 45/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2687 - accuracy: 0.9000 - val_loss: 0.1770 - val_accuracy: 0.9531
#
# Epoch 00045: val_loss improved from 0.18534 to 0.17703, saving model to ieeercnn_vgg16_1.h5
# Epoch 46/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2935 - accuracy: 0.8813 - val_loss: 0.3723 - val_accuracy: 0.8125
#
# Epoch 00046: val_loss did not improve from 0.17703
# Epoch 47/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3281 - accuracy: 0.8594 - val_loss: 0.1609 - val_accuracy: 0.9375
#
# Epoch 00047: val_loss improved from 0.17703 to 0.16085, saving model to ieeercnn_vgg16_1.h5
# Epoch 48/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3511 - accuracy: 0.8406 - val_loss: 0.3477 - val_accuracy: 0.8438
#
# Epoch 00048: val_loss did not improve from 0.16085
# Epoch 49/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2493 - accuracy: 0.8938 - val_loss: 0.4111 - val_accuracy: 0.8438
#
# Epoch 00049: val_loss did not improve from 0.16085
# Epoch 50/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3824 - accuracy: 0.8687 - val_loss: 0.4138 - val_accuracy: 0.8906
#
# Epoch 00050: val_loss did not improve from 0.16085
# Epoch 51/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3447 - accuracy: 0.8375 - val_loss: 0.3123 - val_accuracy: 0.8594
#
# Epoch 00051: val_loss did not improve from 0.16085
# Epoch 52/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2922 - accuracy: 0.8562 - val_loss: 0.3358 - val_accuracy: 0.8594
#
# Epoch 00052: val_loss did not improve from 0.16085
# Epoch 53/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3252 - accuracy: 0.8406 - val_loss: 0.3064 - val_accuracy: 0.9219
#
# Epoch 00053: val_loss did not improve from 0.16085
# Epoch 54/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3049 - accuracy: 0.8531 - val_loss: 0.3228 - val_accuracy: 0.7969
#
# Epoch 00054: val_loss did not improve from 0.16085
# Epoch 55/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2825 - accuracy: 0.8875 - val_loss: 0.2576 - val_accuracy: 0.8906
#
# Epoch 00055: val_loss did not improve from 0.16085
# Epoch 56/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3397 - accuracy: 0.8594 - val_loss: 0.3435 - val_accuracy: 0.8750
#
# Epoch 00056: val_loss did not improve from 0.16085
# Epoch 57/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2818 - accuracy: 0.8875 - val_loss: 0.3378 - val_accuracy: 0.8438
#
# Epoch 00057: val_loss did not improve from 0.16085
# Epoch 58/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2953 - accuracy: 0.8625 - val_loss: 0.2779 - val_accuracy: 0.9062
#
# Epoch 00058: val_loss did not improve from 0.16085
# Epoch 59/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3067 - accuracy: 0.8656 - val_loss: 0.2949 - val_accuracy: 0.8750
#
# Epoch 00059: val_loss did not improve from 0.16085
# Epoch 60/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3147 - accuracy: 0.8750 - val_loss: 0.3695 - val_accuracy: 0.8594
#
# Epoch 00060: val_loss did not improve from 0.16085
# Epoch 61/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3698 - accuracy: 0.8625 - val_loss: 0.3110 - val_accuracy: 0.8594
#
# Epoch 00061: val_loss did not improve from 0.16085
# Epoch 62/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3799 - accuracy: 0.8625 - val_loss: 0.2284 - val_accuracy: 0.9062
#
# Epoch 00062: val_loss did not improve from 0.16085
# Epoch 63/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3248 - accuracy: 0.8687 - val_loss: 0.3747 - val_accuracy: 0.8438
#
# Epoch 00063: val_loss did not improve from 0.16085
# Epoch 64/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3441 - accuracy: 0.8594 - val_loss: 0.3038 - val_accuracy: 0.8438
#
# Epoch 00064: val_loss did not improve from 0.16085
# Epoch 65/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3503 - accuracy: 0.8375 - val_loss: 0.3728 - val_accuracy: 0.8438
#
# Epoch 00065: val_loss did not improve from 0.16085
# Epoch 66/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3684 - accuracy: 0.8438 - val_loss: 0.4227 - val_accuracy: 0.7969
#
# Epoch 00066: val_loss did not improve from 0.16085
# Epoch 67/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3420 - accuracy: 0.8500 - val_loss: 0.2548 - val_accuracy: 0.8906
#
# Epoch 00067: val_loss did not improve from 0.16085
# Epoch 68/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3088 - accuracy: 0.8594 - val_loss: 0.2756 - val_accuracy: 0.8750
#
# Epoch 00068: val_loss did not improve from 0.16085
# Epoch 69/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3040 - accuracy: 0.8656 - val_loss: 0.2987 - val_accuracy: 0.8594
#
# Epoch 00069: val_loss did not improve from 0.16085
# Epoch 70/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3534 - accuracy: 0.8219 - val_loss: 0.2866 - val_accuracy: 0.8906
#
# Epoch 00070: val_loss did not improve from 0.16085
# Epoch 71/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2639 - accuracy: 0.8750 - val_loss: 0.2582 - val_accuracy: 0.8750
#
# Epoch 00071: val_loss did not improve from 0.16085
# Epoch 72/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3127 - accuracy: 0.8656 - val_loss: 0.2404 - val_accuracy: 0.8906
#
# Epoch 00072: val_loss did not improve from 0.16085
# Epoch 73/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2736 - accuracy: 0.8813 - val_loss: 0.2527 - val_accuracy: 0.8906
#
# Epoch 00073: val_loss did not improve from 0.16085
# Epoch 74/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2648 - accuracy: 0.8750 - val_loss: 0.2265 - val_accuracy: 0.8906
#
# Epoch 00074: val_loss did not improve from 0.16085
# Epoch 75/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2690 - accuracy: 0.8719 - val_loss: 0.3684 - val_accuracy: 0.7969
#
# Epoch 00075: val_loss did not improve from 0.16085
# Epoch 76/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3286 - accuracy: 0.8500 - val_loss: 0.3138 - val_accuracy: 0.8438
#
# Epoch 00076: val_loss did not improve from 0.16085
# Epoch 77/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3308 - accuracy: 0.8594 - val_loss: 0.2949 - val_accuracy: 0.8438
#
# Epoch 00077: val_loss did not improve from 0.16085
# Epoch 78/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2805 - accuracy: 0.8656 - val_loss: 0.3806 - val_accuracy: 0.8438
#
# Epoch 00078: val_loss did not improve from 0.16085
# Epoch 79/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3325 - accuracy: 0.8531 - val_loss: 0.2748 - val_accuracy: 0.9219
#
# Epoch 00079: val_loss did not improve from 0.16085
# Epoch 80/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2604 - accuracy: 0.8625 - val_loss: 0.3027 - val_accuracy: 0.8281
#
# Epoch 00080: val_loss did not improve from 0.16085
# Epoch 81/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3418 - accuracy: 0.8625 - val_loss: 0.2927 - val_accuracy: 0.8594
#
# Epoch 00081: val_loss did not improve from 0.16085
# Epoch 82/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3181 - accuracy: 0.8500 - val_loss: 0.3527 - val_accuracy: 0.8906
#
# Epoch 00082: val_loss did not improve from 0.16085
# Epoch 83/1000
# 10/10 [==============================] - 16s 2s/step - loss: 0.2831 - accuracy: 0.8969 - val_loss: 0.3873 - val_accuracy: 0.8438
#
# Epoch 00083: val_loss did not improve from 0.16085
# Epoch 84/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2936 - accuracy: 0.8906 - val_loss: 0.2213 - val_accuracy: 0.9062
#
# Epoch 00084: val_loss did not improve from 0.16085
# Epoch 85/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3949 - accuracy: 0.8531 - val_loss: 0.2478 - val_accuracy: 0.8906
#
# Epoch 00085: val_loss did not improve from 0.16085
# Epoch 86/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2732 - accuracy: 0.8656 - val_loss: 0.4292 - val_accuracy: 0.8438
#
# Epoch 00086: val_loss did not improve from 0.16085
# Epoch 87/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3023 - accuracy: 0.8625 - val_loss: 0.3027 - val_accuracy: 0.8906
#
# Epoch 00087: val_loss did not improve from 0.16085
# Epoch 88/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3095 - accuracy: 0.8687 - val_loss: 0.3320 - val_accuracy: 0.8438
#
# Epoch 00088: val_loss did not improve from 0.16085
# Epoch 89/1000
# 10/10 [==============================] - 16s 2s/step - loss: 0.3510 - accuracy: 0.8469 - val_loss: 0.3888 - val_accuracy: 0.7969
#
# Epoch 00089: val_loss did not improve from 0.16085
# Epoch 90/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3026 - accuracy: 0.8750 - val_loss: 0.2988 - val_accuracy: 0.8125
#
# Epoch 00090: val_loss did not improve from 0.16085
# Epoch 91/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.4623 - accuracy: 0.8719 - val_loss: 0.3053 - val_accuracy: 0.8906
#
# Epoch 00091: val_loss did not improve from 0.16085
# Epoch 92/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2960 - accuracy: 0.8656 - val_loss: 0.2225 - val_accuracy: 0.9219
#
# Epoch 00092: val_loss did not improve from 0.16085
# Epoch 93/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2828 - accuracy: 0.8781 - val_loss: 0.2423 - val_accuracy: 0.9062
#
# Epoch 00093: val_loss did not improve from 0.16085
# Epoch 94/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2870 - accuracy: 0.8719 - val_loss: 0.3505 - val_accuracy: 0.8594
#
# Epoch 00094: val_loss did not improve from 0.16085
# Epoch 95/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3158 - accuracy: 0.8656 - val_loss: 0.4026 - val_accuracy: 0.8125
#
# Epoch 00095: val_loss did not improve from 0.16085
# Epoch 96/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2896 - accuracy: 0.8813 - val_loss: 0.2790 - val_accuracy: 0.8750
#
# Epoch 00096: val_loss did not improve from 0.16085
# Epoch 97/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3555 - accuracy: 0.8469 - val_loss: 0.3331 - val_accuracy: 0.8125
#
# Epoch 00097: val_loss did not improve from 0.16085
# Epoch 98/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3318 - accuracy: 0.8531 - val_loss: 0.2015 - val_accuracy: 0.9062
#
# Epoch 00098: val_loss did not improve from 0.16085
# Epoch 99/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2636 - accuracy: 0.8750 - val_loss: 0.2243 - val_accuracy: 0.8750
#
# Epoch 00099: val_loss did not improve from 0.16085
# Epoch 100/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2513 - accuracy: 0.9062 - val_loss: 0.3526 - val_accuracy: 0.8438
#
# Epoch 00100: val_loss did not improve from 0.16085
# Epoch 101/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2829 - accuracy: 0.8813 - val_loss: 0.1747 - val_accuracy: 0.9375
#
# Epoch 00101: val_loss did not improve from 0.16085
# Epoch 102/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3550 - accuracy: 0.8594 - val_loss: 0.2712 - val_accuracy: 0.8750
#
# Epoch 00102: val_loss did not improve from 0.16085
# Epoch 103/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2918 - accuracy: 0.8719 - val_loss: 0.1750 - val_accuracy: 0.9375
#
# Epoch 00103: val_loss did not improve from 0.16085
# Epoch 104/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3292 - accuracy: 0.8594 - val_loss: 0.2243 - val_accuracy: 0.8906
#
# Epoch 00104: val_loss did not improve from 0.16085
# Epoch 105/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3835 - accuracy: 0.8188 - val_loss: 0.3069 - val_accuracy: 0.8438
#
# Epoch 00105: val_loss did not improve from 0.16085
# Epoch 106/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3345 - accuracy: 0.8562 - val_loss: 0.3070 - val_accuracy: 0.8281
#
# Epoch 00106: val_loss did not improve from 0.16085
# Epoch 107/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3285 - accuracy: 0.8750 - val_loss: 0.2620 - val_accuracy: 0.8750
#
# Epoch 00107: val_loss did not improve from 0.16085
# Epoch 108/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3358 - accuracy: 0.8625 - val_loss: 0.2974 - val_accuracy: 0.8750
#
# Epoch 00108: val_loss did not improve from 0.16085
# Epoch 109/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3568 - accuracy: 0.8531 - val_loss: 0.5084 - val_accuracy: 0.7969
#
# Epoch 00109: val_loss did not improve from 0.16085
# Epoch 110/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3047 - accuracy: 0.8687 - val_loss: 0.2301 - val_accuracy: 0.9219
#
# Epoch 00110: val_loss did not improve from 0.16085
# Epoch 111/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2900 - accuracy: 0.8906 - val_loss: 0.4762 - val_accuracy: 0.7969
#
# Epoch 00111: val_loss did not improve from 0.16085
# Epoch 112/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2969 - accuracy: 0.8813 - val_loss: 0.2468 - val_accuracy: 0.8750
#
# Epoch 00112: val_loss did not improve from 0.16085
# Epoch 113/1000
# 10/10 [==============================] - 16s 2s/step - loss: 0.3861 - accuracy: 0.8531 - val_loss: 0.3654 - val_accuracy: 0.8438
#
# Epoch 00113: val_loss did not improve from 0.16085
# Epoch 114/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2445 - accuracy: 0.8969 - val_loss: 0.5415 - val_accuracy: 0.7188
#
# Epoch 00114: val_loss did not improve from 0.16085
# Epoch 115/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3276 - accuracy: 0.8562 - val_loss: 0.2168 - val_accuracy: 0.9219
#
# Epoch 00115: val_loss did not improve from 0.16085
# Epoch 116/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2855 - accuracy: 0.8687 - val_loss: 0.2105 - val_accuracy: 0.9531
#
# Epoch 00116: val_loss did not improve from 0.16085
# Epoch 117/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2610 - accuracy: 0.9000 - val_loss: 0.2974 - val_accuracy: 0.8750
#
# Epoch 00117: val_loss did not improve from 0.16085
# Epoch 118/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2071 - accuracy: 0.9187 - val_loss: 0.2581 - val_accuracy: 0.9219
#
# Epoch 00118: val_loss did not improve from 0.16085
# Epoch 119/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2970 - accuracy: 0.8625 - val_loss: 0.2302 - val_accuracy: 0.8906
#
# Epoch 00119: val_loss did not improve from 0.16085
# Epoch 120/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2665 - accuracy: 0.8875 - val_loss: 0.3915 - val_accuracy: 0.8281
#
# Epoch 00120: val_loss did not improve from 0.16085
# Epoch 121/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3473 - accuracy: 0.8281 - val_loss: 0.1766 - val_accuracy: 0.9219
#
# Epoch 00121: val_loss did not improve from 0.16085
# Epoch 122/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2634 - accuracy: 0.9031 - val_loss: 0.3337 - val_accuracy: 0.8594
#
# Epoch 00122: val_loss did not improve from 0.16085
# Epoch 123/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3492 - accuracy: 0.8562 - val_loss: 0.3221 - val_accuracy: 0.8594
#
# Epoch 00123: val_loss did not improve from 0.16085
# Epoch 124/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3128 - accuracy: 0.8687 - val_loss: 0.2361 - val_accuracy: 0.9062
#
# Epoch 00124: val_loss did not improve from 0.16085
# Epoch 125/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2646 - accuracy: 0.8906 - val_loss: 0.4222 - val_accuracy: 0.8438
#
# Epoch 00125: val_loss did not improve from 0.16085
# Epoch 126/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2683 - accuracy: 0.8750 - val_loss: 0.3188 - val_accuracy: 0.9062
#
# Epoch 00126: val_loss did not improve from 0.16085
# Epoch 127/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3178 - accuracy: 0.8750 - val_loss: 0.3320 - val_accuracy: 0.8594
#
# Epoch 00127: val_loss did not improve from 0.16085
# Epoch 128/1000
# 10/10 [==============================] - 15s 2s/step - loss: 0.4025 - accuracy: 0.8231 - val_loss: 0.3459 - val_accuracy: 0.8906
#
# Epoch 00128: val_loss did not improve from 0.16085
# Epoch 129/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3111 - accuracy: 0.8625 - val_loss: 0.2465 - val_accuracy: 0.8906
#
# Epoch 00129: val_loss did not improve from 0.16085
# Epoch 130/1000
# 10/10 [==============================] - 16s 2s/step - loss: 0.2771 - accuracy: 0.8844 - val_loss: 0.3561 - val_accuracy: 0.8281
#
# Epoch 00130: val_loss did not improve from 0.16085
# Epoch 131/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2805 - accuracy: 0.8875 - val_loss: 0.2830 - val_accuracy: 0.8906
#
# Epoch 00131: val_loss did not improve from 0.16085
# Epoch 132/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3225 - accuracy: 0.8500 - val_loss: 0.2621 - val_accuracy: 0.8594
#
# Epoch 00132: val_loss did not improve from 0.16085
# Epoch 133/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2897 - accuracy: 0.8813 - val_loss: 0.3265 - val_accuracy: 0.8594
#
# Epoch 00133: val_loss did not improve from 0.16085
# Epoch 134/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2384 - accuracy: 0.9094 - val_loss: 0.3212 - val_accuracy: 0.8438
#
# Epoch 00134: val_loss did not improve from 0.16085
# Epoch 135/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3729 - accuracy: 0.8188 - val_loss: 0.3157 - val_accuracy: 0.7969
#
# Epoch 00135: val_loss did not improve from 0.16085
# Epoch 136/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3064 - accuracy: 0.8656 - val_loss: 0.3068 - val_accuracy: 0.8750
#
# Epoch 00136: val_loss did not improve from 0.16085
# Epoch 137/1000
# 10/10 [==============================] - 16s 2s/step - loss: 0.3165 - accuracy: 0.8469 - val_loss: 0.3133 - val_accuracy: 0.8125
#
# Epoch 00137: val_loss did not improve from 0.16085
# Epoch 138/1000
# 10/10 [==============================] - 16s 2s/step - loss: 0.2757 - accuracy: 0.8875 - val_loss: 0.2214 - val_accuracy: 0.8906
#
# Epoch 00138: val_loss did not improve from 0.16085
# Epoch 139/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2690 - accuracy: 0.8969 - val_loss: 0.3778 - val_accuracy: 0.7969
#
# Epoch 00139: val_loss did not improve from 0.16085
# Epoch 140/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3531 - accuracy: 0.8500 - val_loss: 0.2468 - val_accuracy: 0.8906
#
# Epoch 00140: val_loss did not improve from 0.16085
# Epoch 141/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3001 - accuracy: 0.8719 - val_loss: 0.2516 - val_accuracy: 0.8438
#
# Epoch 00141: val_loss did not improve from 0.16085
# Epoch 142/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.2494 - accuracy: 0.8875 - val_loss: 0.3021 - val_accuracy: 0.8594
#
# Epoch 00142: val_loss did not improve from 0.16085
# Epoch 143/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3822 - accuracy: 0.8313 - val_loss: 0.2813 - val_accuracy: 0.8594
#
# Epoch 00143: val_loss did not improve from 0.16085
# Epoch 144/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3215 - accuracy: 0.8906 - val_loss: 0.3884 - val_accuracy: 0.7969
#
# Epoch 00144: val_loss did not improve from 0.16085
# Epoch 145/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.4304 - accuracy: 0.8344 - val_loss: 0.4150 - val_accuracy: 0.8594
#
# Epoch 00145: val_loss did not improve from 0.16085
# Epoch 146/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3730 - accuracy: 0.8531 - val_loss: 0.2924 - val_accuracy: 0.8750
#
# Epoch 00146: val_loss did not improve from 0.16085
# Epoch 147/1000
# 10/10 [==============================] - 17s 2s/step - loss: 0.3028 - accuracy: 0.8594 - val_loss: 0.2759 - val_accuracy: 0.8750
#
# Epoch 00147: val_loss did not improve from 0.16085
# Epoch 00147: early stopping

# %%
import matplotlib.pyplot as plt
# plt.plot(hist.history["acc"])
# plt.plot(hist.history['val_acc'])
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title("model loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Loss","Validation Loss"])
plt.show()
plt.savefig('chart loss.png')

# %%
im = X_test[1600]
plt.imshow(im)
img = np.expand_dims(im, axis=0)
out= model_final.predict(img)
if out[0][0] > out[0][1]:
    print("plane")
else:
    print("not plane")
# Out:
# plane

# %%
z=0
for e,i in enumerate(os.listdir(path)):
    if i.startswith("4"):
        z += 1
        img = cv2.imread(os.path.join(path,i))
        ss.setBaseImage(img)
        ss.switchToSelectiveSearchFast()
        ssresults = ss.process()
        imout = img.copy()
        for e,result in enumerate(ssresults):
            if e < 2000:
                x,y,w,h = result
                timage = imout[y:y+h,x:x+w]
                resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
                img = np.expand_dims(resized, axis=0)
                out= model_final.predict(img)
                if out[0][0] > 0.65:
                    cv2.rectangle(imout, (x, y), (x+w, y+h), (0, 255, 0), 1, cv2.LINE_AA)
        plt.figure()
        plt.imshow(imout)
